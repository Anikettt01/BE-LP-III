# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales_data_sample.csv",encoding='latin1')
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# 2  27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3             78934 Hillside Dr.           NaN       Pasadena    CA
# 4                7734 Strong St.           NaN  San Francisco    CA
#
#   POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA       NaN              Yu             Kwai    Small
# 1      51100  France      EMEA         Henriot             Paul    Small
# 2      75508  France      EMEA        Da Cunha           Daniel   Medium
# 3      90003     USA       NaN           Young            Julie   Medium
# 4        NaN     USA       NaN           Brown            Julie   Medium
#
# [5 rows x 25 columns]

# %%
df_numeric = df.select_dtypes(include=['int64','float64'])
df_numeric.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  QTR_ID  \
# 0        10107               30      95.70                2  2871.00       1
# 1        10121               34      81.35                5  2765.90       2
# 2        10134               41      94.74                2  3884.34       3
# 3        10145               45      83.26                6  3746.70       3
# 4        10159               49     100.00               14  5205.27       4
#
#    MONTH_ID  YEAR_ID  MSRP
# 0         2     2003    95
# 1         5     2003    95
# 2         7     2003    95
# 3         8     2003    95
# 4        10     2003    95

# %%
df_numeric.isnull().sum()
# Out:
# ORDERNUMBER        0
# QUANTITYORDERED    0
# PRICEEACH          0
# ORDERLINENUMBER    0
# SALES              0
# QTR_ID             0
# MONTH_ID           0
# YEAR_ID            0
# MSRP               0
# dtype: int64

# %%
from sklearn.cluster import KMeans
wcss = []
for k in range (1,11):
  km = KMeans(n_clusters=k,random_state=42)
  km.fit(df_numeric)
  wcss.append(km.inertia_)

plt.plot(range(1,11),wcss)
plt.xlabel("number of clusters(k)")
plt.ylabel("WCSS")
plt.title("Elbow method")
plt.show()

# %%
kmeans=KMeans(n_clusters=4,random_state=42)
clusters=kmeans.fit_predict(df_numeric)
df['Cluster']=clusters
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# 1          Reims   NaN      51100  France      EMEA         Henriot
# 2          Paris   NaN      75508  France      EMEA        Da Cunha
# 3       Pasadena    CA      90003     USA       NaN           Young
# 4  San Francisco    CA        NaN     USA       NaN           Brown
#
#   CONTACTFIRSTNAME DEALSIZE Cluster
# 0             Kwai    Small       3
# 1             Paul    Small       3
# 2           Daniel   Medium       3
# 3            Julie   Medium       3
# 4            Julie   Medium       1
#
# [5 rows x 26 columns]

# %%
df.groupby('Cluster').mean(numeric_only=True)
# Out:
#           ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# Cluster
# 0        10258.862500        29.879808  65.471269         6.615385
# 1        10257.537367        40.749110  99.542260         6.266904
# 2        10272.834171        46.371859  99.841859         5.527638
# 3        10256.491194        35.090998  90.280499         6.606654
#
#                SALES    QTR_ID  MONTH_ID      YEAR_ID        MSRP
# Cluster
# 0        1884.935173  2.723077  7.127885  2003.816346   73.389423
# 1        5301.385676  2.733096  7.129893  2003.804270  127.149466
# 2        7983.625477  2.658291  6.899497  2003.919598  154.291457
# 3        3428.743689  2.715264  7.073386  2003.799413  103.554795
